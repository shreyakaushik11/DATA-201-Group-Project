# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
df = pd.read_csv("../datacleaning/laptops_cleaned.csv")

print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"Any inf remaining: {np.isinf(df.select_dtypes(include='number')).any().any()}")
# Out:
# Shape: (2160, 19)
# Columns: ['laptop', 'brand', 'model', 'cpu', 'ram', 'storage', 'storage_type', 'gpu', 'screen', 'final_price', 'cpu_brand', 'cpu_series', 'touch', 'is_new', 'has_discrete_gpu', 'price_per_ram_gb', 'price_per_storage_gb', 'price_tier', 'ram_tier']
# Any inf remaining: False

# %%
try:
    df.to_sql("laptops_cleaned", con=engine, if_exists="replace", index=False)
    print(f"✓ {len(df)} rows loaded into MySQL table 'laptops'")
except Exception as e:
    print(f"ERROR: {e}")
# Out:
# ✓ 2160 rows loaded into MySQL table 'laptops'

# %%
# Replace 'yourpassword' with your actual MySQL root password
engine = create_engine("mysql+mysqlconnector://root:tromb0n3@localhost/laptops_db")

# %%
try:
    df.to_sql("laptops", con=engine, if_exists="replace", index=False)
    print(f"✓ {len(df)} rows loaded into MySQL table 'laptops'")
except Exception as e:
    print(f"ERROR: {e}")
# Out:
# ✓ 2160 rows loaded into MySQL table 'laptops'

# %%
result = pd.read_sql("SELECT * FROM laptops LIMIT 5", engine)
result
# Out:
#                                               laptop   brand       model  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    ASUS  ExpertBook
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...  Alurin          Go
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    ASUS  ExpertBook
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...     MSI      Katana
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...      HP         15S
#
#              cpu  ram  storage storage_type         gpu  screen  final_price  \
# 0  Intel Core i5    8      512          SSD  Integrated    15.6      1009.00
# 1  Intel Celeron    8      256          SSD  Integrated    15.6       299.00
# 2  Intel Core i3    8      256          SSD  Integrated    15.6       789.00
# 3  Intel Core i7   16     1000          SSD    RTX 3050    15.6      1199.00
# 4  Intel Core i5   16      512          SSD  Integrated    15.6       669.01
#
#   cpu_brand cpu_series  touch  is_new  has_discrete_gpu  price_per_ram_gb  \
# 0     Intel    Core i5      0       1                 0            126.12
# 1     Intel    Celeron      0       1                 0             37.38
# 2     Intel    Core i3      0       1                 0             98.62
# 3     Intel    Core i7      0       1                 1             74.94
# 4     Intel    Core i5      0       1                 0             41.81
#
#    price_per_storage_gb price_tier     ram_tier
# 0                1.9707   High-end  Low (<=8GB)
# 1                1.1680     Budget  Low (<=8GB)
# 2                3.0820  Mid-range  Low (<=8GB)
# 3                1.1990   High-end   Mid (16GB)
# 4                1.3067  Mid-range   Mid (16GB)

# %%
query1 = pd.read_sql("""
    SELECT brand, 
           ROUND(AVG(final_price), 2) AS avg_price,
           COUNT(*) AS total_laptops
    FROM laptops
    GROUP BY brand
    ORDER BY avg_price DESC
""", engine)

query1
# Out:
#                brand  avg_price  total_laptops
# 0              Razer    3265.70             37
# 1          Millenium    1976.84              2
# 2                MSI    1913.45            308
# 3                 LG    1730.03             32
# 4           Gigabyte    1698.49             48
# 5              Pccom    1606.76             24
# 6          Microsoft    1595.54             77
# 7            Samsung    1595.51             22
# 8              Apple    1578.23            116
# 9        Deep Gaming    1505.38              8
# 10              ASUS    1269.38            415
# 11              Dell    1153.84             84
# 12            Lenovo    1087.72            366
# 13              Vant    1047.46             11
# 14              Acer    1001.29            137
# 15  Dynabook Toshiba     999.20             19
# 16            Realme     999.00              1
# 17                HP     952.63            368
# 18            Medion     905.33             32
# 19           Toshiba     799.00              1
# 20            Alurin     484.70             29
# 21           Jetwing     469.27              1
# 22            Innjoo     347.89              6
# 23            Primux     339.62              8
# 24            Denver     329.95              1
# 25           Thomson     316.86              4
# 26           Prixton     292.28              3
